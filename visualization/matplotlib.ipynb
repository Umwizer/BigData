# %% [markdown]
# 1.Import Matplotlib and plot a line graph
# 2.Create a bar chart showing student scores.
# 3.Plot a scatter graph of height vs weight.
# 4.Create a histogram of 100 random numbers.
# 5.Plot multiple lines on the same graph.

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3], [4, 5, 6])
students = ['A','B','C','D']
scores = [20,30,25,25]
plt.show()

# %%
import matplotlib.pyplot as plt 
height=[150,160,170]
weight=[50,60,70]
plt.scatter(height,weight)
plt.show()

# %%
import numpy as np
plt.hist(np.random.rand(100))
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3], [4,5,6])
plt.plot([1,2,3], [6,5,4])
plt.show()
